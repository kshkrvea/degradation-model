# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from PIL import Image, ImageFilter

import torch

from skimage.metrics import mean_squared_error as mse
from skimage import io

import cv2 as cv

import time

import random
random.seed(999)

from codes import my_loader
from  codes import my_utils 

from sklearn.metrics import mean_squared_error as mse
from tqdm import tqdm

from codes.GAN_class import DownsampleGAN


print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# True

# %%
gan = my_utils.load_model('./saved_models/checkpoints3/mod_0')   
gan.empty_val_losses()
for i in range(10):
    gan.load_weights('./weights/checkpoints/netG_' + str(i), './weights/checkpoints/netD_' + str(i))    
    gan.test(i, {'PSNR', 'LPIPS', 'SSIM'})
    my_utils.save_model(gan, './saved_models/checkpoints5/mod_' + str(i))
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /home/ezgor/anaconda3/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth
# 100%|███████████████████████████████████████| 2500/2500 [15:09<00:00,  2.75it/s]
# Test Generator loss after 3 epoch =  2.173747428178787
# Test Discriminator loss after 3 epoch =  1.4135025428295136
# Test PSNR after 3 epoch =  26.493882532711222
# Test SSIM after 3 epoch =  0.9373505916184302
# Test LPIPS after 3 epoch =  0.03284508362412453
# Average time for one 1024x512 px frame processing:  0.07369792881011963
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /home/ezgor/anaconda3/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth
# 100%|███████████████████████████████████████| 2500/2500 [15:12<00:00,  2.74it/s]
# Test Generator loss after 4 epoch =  2.011028523683548
# Test Discriminator loss after 4 epoch =  1.3720030433654786
# Test PSNR after 4 epoch =  26.676358343045653
# Test SSIM after 4 epoch =  0.9383541981230932
# Test LPIPS after 4 epoch =  0.03278682753443718
# Average time for one 1024x512 px frame processing:  0.07432611112594605
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /home/ezgor/anaconda3/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth
# 100%|███████████████████████████████████████| 2500/2500 [15:53<00:00,  2.62it/s]
# Test Generator loss after 5 epoch =  2.0451390107631684
# Test Discriminator loss after 5 epoch =  1.3958762814998626
# Test PSNR after 5 epoch =  26.745143148064155
# Test SSIM after 5 epoch =  0.9385166717132619
# Test LPIPS after 5 epoch =  0.03203019127249718
# Average time for one 1024x512 px frame processing:  0.07553690929412842
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /home/ezgor/anaconda3/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth
# 100%|███████████████████████████████████████| 2500/2500 [15:20<00:00,  2.72it/s]
# Test Generator loss after 6 epoch =  1.995068708896637
# Test Discriminator loss after 6 epoch =  1.3879556133270263
# Test PSNR after 6 epoch =  26.75009899751019
# Test SSIM after 6 epoch =  0.9387667901265547
# Test LPIPS after 6 epoch =  0.032430801540613174
# Average time for one 1024x512 px frame processing:  0.0739424373626709

# %%
gan = my_utils.load_model('./saved_models/checkpoints5/mod_9')

# %%
ep = len(gan.validation_losses['G']['PSNR'])
for x in gan.validation_losses['BC']:
    plt.plot(range(ep), gan.validation_losses['G'][x], label = 'GAN')
    plt.plot(range(ep), [gan.validation_losses['BC'][x] for i in range(ep)], label = "Bicubic")
    plt.plot(range(ep), [gan.validation_losses['BC6'][x] for i in range(ep)], label = "Bicubic6x")
    plt.plot(range(ep), [gan.validation_losses['GS'][x] for i in range(ep)], label = "Gauss")
    plt.legend()
    plt.xlabel('epochs')
    plt.ylabel(x)
    plt.show()

# %%
plt.plot(range(ep), gan.validation_losses['G']['GAN'], label = 'Generator')
plt.plot(range(ep), gan.validation_losses['D'], label = 'Discriminator')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()
